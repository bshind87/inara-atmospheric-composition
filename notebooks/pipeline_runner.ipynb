# %%
import os
import sys

# Get project root (one level up from notebooks/)
PROJECT_ROOT = os.path.abspath("..")

# Add src to path
SRC_PATH = os.path.join(PROJECT_ROOT, "src")
sys.path.append(SRC_PATH)

print("Project root:", PROJECT_ROOT)
print("Src path:", SRC_PATH)
# Out:
# Project root: /Users/bhalchandra/PycharmProjects/inara-atmospheric-composition
# Src path: /Users/bhalchandra/PycharmProjects/inara-atmospheric-composition/src

# %%
import subprocess

def run_script(script_name, args=None):
    cmd = ["python", os.path.join(SRC_PATH, script_name)]

    if args:
        cmd.extend(args)

    print(f"\nRunning: {' '.join(cmd)}\n")

    result = subprocess.run(cmd, capture_output=True, text=True)

    print(result.stdout)

    if result.stderr:
        print("ERROR:\n", result.stderr)

    if result.returncode != 0:
        raise Exception(f"{script_name} failed!")

# %%
#run_script("download_inara.py")
# Out:
# Running: python /Users/bhalchandra/PycharmProjects/inara-atmospheric-composition/src/download_inara.py
#
#
#   Molecule     Mean     Std     Min     Max
#   --------------------------------------------
#   H2O         -1.94    1.37   -4.57    0.00
#   CO2         -2.23    0.84   -5.01   -0.09
#   O2          -1.68    0.52   -2.81   -0.46
#   O3          -6.15    0.39   -7.14   -5.10
#   CH4         -4.90    0.85   -6.26   -1.92
#   N2            nan     nan     nan     nan
#   N2O           nan     nan     nan     nan
#   CO            nan     nan     nan     nan
#   H2            nan     nan     nan     nan
#   H2S           nan     nan     nan     nan
#   SO2           nan     nan     nan     nan
#   NH3           nan     nan     nan     nan
#
# ERROR:
#  15:31:11  Found 214 CSV files in /Users/bhalchandra/PycharmProjects/inara-atmospheric-composition/inara_data
# 15:31:11  Labels loaded: (214, 24)  columns: ['H2O', 'CO2', 'O2', 'O3', 'CH4', 'N2', 'N2O', 'CO', 'H2', 'H2S', 'SO2', 'NH3', 'stellar_type', 'stellar_teff', 'stellar_radius', 'planet_radius', 'planet_mass', 'surface_gravity', 'orbital_distance', 'surface_pressure', 'snr_mean', 'snr_max', 'rp_rs_sq', 'retrieval_quality']
# 15:31:12  Parsed 214 ok | 0 failed/missing labels
# 15:31:12  Saved to /Users/bhalchandra/PycharmProjects/inara-atmospheric-composition/inara_data/processed:
# 15:31:12    spectra.npy     (214, 3, 4378)
# 15:31:12    molecules.npy   (214, 12)
# 15:31:12    aux_params.npy  (214, 8)

# %%
run_script("feature_engineering.py")
# Out:
# Running: python /Users/bhalchandra/PycharmProjects/inara-atmospheric-composition/src/feature_engineering.py
#
# Loaded data:
# Spectra: (10000, 3, 4378)
# Targets: (10000, 12)
# Raw feature matrix shape: (10000, 79)
# Final feature matrix shape: (10000, 74)
# Features saved successfully 🚀

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Load data
X = np.load("../inara_data/features/X.npy")
targets = np.load("../inara_data/features/targets.npy")

print("y_test:", X.shape)
print("y_pred:", targets.shape)

# Recreate the same split
#X_train, X_test, y_train, y_test = train_test_split(
#    X, targets, test_size=0.2, random_state=42
#)

# Load predictions
#y_pred = np.load("rf_predictions.npy")

#print("y_test:", y_test.shape)
#print("y_pred:", y_pred.shape)
# Out:
# y_test: (10000, 74)
# y_pred: (10000, 12)

# %%
# !pip install --upgrade xgboost
# Out:
# Requirement already satisfied: xgboost in /opt/anaconda3/envs/ML/lib/python3.13/site-packages (3.1.3)
# Collecting xgboost
#   Downloading xgboost-3.2.0-py3-none-macosx_12_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/ML/lib/python3.13/site-packages (from xgboost) (2.4.3)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/ML/lib/python3.13/site-packages (from xgboost) (1.16.3)
# Downloading xgboost-3.2.0-py3-none-macosx_12_0_arm64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 9.9 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: xgboost
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 3.1.3
#     Uninstalling xgboost-3.1.3:
#       Successfully uninstalled xgboost-3.1.3
# Successfully installed xgboost-3.2.0
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np

run_script("xgboost_feature_engineering.py")
# Load data
X = np.load("../inara_data/features/X.npy")
targets = np.load("../inara_data/features/targets.npy")

print("y_test:", X.shape)
print("y_pred:", targets.shape)
# Out:
# Running: python /Users/bhalchandra/PycharmProjects/inara-atmospheric-composition/src/xgboost_feature_engineering.py
#
# Loaded data:
# Spectra: (10000, 3, 4378)
# Targets: (10000, 12)
# Processing 0/10000
# Processing 5000/10000
# Raw feature matrix shape: (10000, 755)
# Final feature matrix shape: (10000, 748)
# Features saved successfully 🚀
#
# y_test: (10000, 748)
# y_pred: (10000, 12)

# %%
run_script("xgboost_train.py")
# Out:
# Running: python /Users/bhalchandra/PycharmProjects/inara-atmospheric-composition/src/xgboost_train.py
#
# Loaded: (10000, 748) (10000, 12)
#
# Training per-molecule models...
#
# Training molecule 0...
# Training molecule 1...
# Training molecule 2...
# Training molecule 3...
# Training molecule 4...
# Training molecule 5...
# Training molecule 6...
# Training molecule 7...
# Training molecule 8...
# Training molecule 9...
# Training molecule 10...
# Training molecule 11...
#
# === VALIDATION RESULTS ===
# R2   : 0.3601464331150055
# RMSE : 0.9685204449289291
# MAE  : 0.6168034672737122
#
# Per Molecule:
# Molecule 00 → R2=0.911, RMSE=0.411
# Molecule 01 → R2=0.935, RMSE=0.225
# Molecule 02 → R2=0.986, RMSE=0.063
# Molecule 03 → R2=0.999, RMSE=0.010
# Molecule 04 → R2=0.926, RMSE=0.225
# Molecule 05 → R2=-0.068, RMSE=0.757
# Molecule 06 → R2=-0.075, RMSE=1.009
# Molecule 07 → R2=-0.070, RMSE=1.507
# Molecule 08 → R2=-0.060, RMSE=1.526
# Molecule 09 → R2=-0.043, RMSE=1.165
# Molecule 10 → R2=-0.057, RMSE=1.132
# Molecule 11 → R2=-0.063, RMSE=1.467
#
# Models saved 🚀

# %%
run_script("xgboost_evaluate.py")
# Out:
# Running: python /Users/bhalchandra/PycharmProjects/inara-atmospheric-composition/src/xgboost_evaluate.py
#
#
# Overall Metrics:
# R2   : 0.8041892647743225
# RMSE : 0.5303047690786202
# MAE  : 0.1860112100839615
#
# Per Molecule Metrics:
# Molecule 00 → R2=0.972, RMSE=0.228, MAE=0.060
# Molecule 01 → R2=0.978, RMSE=0.131, MAE=0.034
# Molecule 02 → R2=0.996, RMSE=0.035, MAE=0.012
# Molecule 03 → R2=1.000, RMSE=0.005, MAE=0.001
# Molecule 04 → R2=0.975, RMSE=0.129, MAE=0.034
# Molecule 05 → R2=0.670, RMSE=0.420, MAE=0.188
# Molecule 06 → R2=0.665, RMSE=0.548, MAE=0.245
# Molecule 07 → R2=0.670, RMSE=0.831, MAE=0.369
# Molecule 08 → R2=0.688, RMSE=0.832, MAE=0.369
# Molecule 09 → R2=0.689, RMSE=0.636, MAE=0.284
# Molecule 10 → R2=0.675, RMSE=0.622, MAE=0.278
# Molecule 11 → R2=0.672, RMSE=0.798, MAE=0.358

# %%
## Next steps as below

# %% [markdown]
# Execute Random Forest baseline + evaluation + Visualization

# %% [markdown]
# Execute XGBoost + evaluation + Visualization

# %% [markdown]
# Model comparison and deployment

# %% [markdown]
# Once all models are implemented, validated and fine tuned, implement AirFlow DAG for ML Pipeline and get the job created to execute end to end process and deploy the model

# %% [markdown]
# Create a web service to call the model.predict using a portal with small data or buck data using a csv file
