# %%
import os
import sys

# Get project root (one level up from notebooks/)
PROJECT_ROOT = os.path.abspath("..")

# Add src to path
SRC_PATH = os.path.join(PROJECT_ROOT, "src")
sys.path.append(SRC_PATH)

print("Project root:", PROJECT_ROOT)
print("Src path:", SRC_PATH)
# Out:
# Project root: /Users/bhalchandra/myPythonCode/inara-atmospheric-composition
# Src path: /Users/bhalchandra/myPythonCode/inara-atmospheric-composition/src

# %%
import subprocess

def run_script(script_name, args=None):
    cmd = ["python", os.path.join(SRC_PATH, script_name)]

    if args:
        cmd.extend(args)

    print(f"\nRunning: {' '.join(cmd)}\n")

    result = subprocess.run(cmd, capture_output=True, text=True)

    print(result.stdout)

    if result.stderr:
        print("ERROR:\n", result.stderr)

    if result.returncode != 0:
        raise Exception(f"{script_name} failed!")

# %%
#run_script("download_inara.py")

# %%
run_script("feature_engineering.py")
# Out:
# Running: python /Users/bhalchandra/PycharmProjects/inara-atmospheric-composition/src/feature_engineering.py
#
# Loaded data:
# Spectra: (10000, 3, 4378)
# Targets: (10000, 12)
# Raw feature matrix shape: (10000, 79)
# Final feature matrix shape: (10000, 74)
# Features saved successfully 🚀

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Load data
X = np.load("../inara_data/features/X.npy")
targets = np.load("../inara_data/features/targets.npy")

print("y_test:", X.shape)
print("y_pred:", targets.shape)

# Recreate the same split
#X_train, X_test, y_train, y_test = train_test_split(
#    X, targets, test_size=0.2, random_state=42
#)

# Load predictions
#y_pred = np.load("rf_predictions.npy")

#print("y_test:", y_test.shape)
#print("y_pred:", y_pred.shape)
# Out:
# y_test: (10000, 748)
# y_pred: (10000, 12)

# %%
#!pip install --upgrade xgboost
# Out:
# Requirement already satisfied: xgboost in /opt/anaconda3/envs/ML/lib/python3.13/site-packages (3.1.3)
# Collecting xgboost
#   Downloading xgboost-3.2.0-py3-none-macosx_12_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/ML/lib/python3.13/site-packages (from xgboost) (2.4.3)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/ML/lib/python3.13/site-packages (from xgboost) (1.16.3)
# Downloading xgboost-3.2.0-py3-none-macosx_12_0_arm64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 9.9 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: xgboost
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 3.1.3
#     Uninstalling xgboost-3.1.3:
#       Successfully uninstalled xgboost-3.1.3
# Successfully installed xgboost-3.2.0
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np

#run_script("xgboost_feature_engineering.py")
run_script("xgboost_feature_eng_v2.py")
# Load data
X = np.load("../inara_data/features/X.npy")
targets = np.load("../inara_data/features/targets.npy")

print("y_test:", X.shape)
print("y_pred:", targets.shape)
# Out:
# Running: python /Users/bhalchandra/myPythonCode/inara-atmospheric-composition/src/xgboost_feature_eng_v2.py
#
# Loading data...
# Loaded data:
# Spectra: (10000, 3, 4378)
# Targets: (10000, 12)
# Processing 0/10000
# Processing 5000/10000
# Raw feature matrix shape: (10000, 887)
# Final feature matrix shape: (10000, 885)
# Features + selector saved successfully 🚀
#
# y_test: (10000, 885)
# y_pred: (10000, 12)

# %%
run_script("xgboost_train.py")
#run_script("mor_xgboost.py")
# Out:
# Running: python /Users/bhalchandra/myPythonCode/inara-atmospheric-composition/src/xgboost_train.py
#
# Loaded: (10000, 885)
# X shape: (10000, 885)
# y shape: (10000, 12)
#
# === Training STRONG molecules ===
#
# === Training WEAK molecules ===
#
# === VALIDATION METRICS ===
# R2   : 0.35186371207237244
# RMSE : 0.972504017877982
# MAE  : 0.618933379650116
#
# === PER MOLECULE ===
# H2O → R2=0.929, RMSE=0.368, MAE=0.170
# CO2 → R2=0.936, RMSE=0.223, MAE=0.110
# O2 → R2=0.986, RMSE=0.064, MAE=0.044
# O3 → R2=0.999, RMSE=0.013, MAE=0.002
# CH4 → R2=0.924, RMSE=0.228, MAE=0.115
# N2 → R2=-0.127, RMSE=0.777, MAE=0.642
# N2O → R2=-0.084, RMSE=1.013, MAE=0.826
# CO → R2=-0.059, RMSE=1.499, MAE=1.205
# H2 → R2=-0.077, RMSE=1.539, MAE=1.246
# H2S → R2=-0.053, RMSE=1.171, MAE=0.954
# SO2 → R2=-0.063, RMSE=1.135, MAE=0.914
# NH3 → R2=-0.087, RMSE=1.484, MAE=1.199
#
# Training complete 🚀

# %%
run_script("xgboost_evaluate.py")
# Out:
# Running: python /Users/bhalchandra/myPythonCode/inara-atmospheric-composition/src/xgboost_evaluate.py
#
#
# === TEST METRICS ===
# R2   : 0.3442852795124054
# RMSE : 0.975622197452017
# MAE  : 0.6187105774879456
#
# === PER MOLECULE ===
# H2O → R2=0.931, RMSE=0.360, MAE=0.172
# CO2 → R2=0.916, RMSE=0.253, MAE=0.113
# O2 → R2=0.984, RMSE=0.066, MAE=0.044
# O3 → R2=0.997, RMSE=0.021, MAE=0.003
# CH4 → R2=0.922, RMSE=0.225, MAE=0.116
# N2 → R2=-0.116, RMSE=0.789, MAE=0.645
# N2O → R2=-0.094, RMSE=1.000, MAE=0.805
# CO → R2=-0.080, RMSE=1.549, MAE=1.246
# H2 → R2=-0.087, RMSE=1.544, MAE=1.236
# H2S → R2=-0.079, RMSE=1.158, MAE=0.934
# SO2 → R2=-0.077, RMSE=1.139, MAE=0.928
# NH3 → R2=-0.085, RMSE=1.460, MAE=1.183

# %%
## Next steps as below

# %% [markdown]
# Execute Random Forest baseline + evaluation + Visualization

# %% [markdown]
# Execute XGBoost + evaluation + Visualization

# %% [markdown]
# Model comparison and deployment

# %% [markdown]
# Once all models are implemented, validated and fine tuned, implement AirFlow DAG for ML Pipeline and get the job created to execute end to end process and deploy the model

# %% [markdown]
# Create a web service to call the model.predict using a portal with small data or buck data using a csv file

# %%
import numpy as np

# Load data
X = np.load("../inara_data/features/X.npy")
targets = np.load("../inara_data/features/targets.npy")

# %%
X[:20]
# Out:
# array([[2.6764226e-01, 3.1187880e-01, 1.8533162e-03, ..., 3.0000000e+00,
#         3.2978999e+03, 7.0142813e-02],
#        [4.6291348e-01, 3.3849087e-01, 7.9219081e-02, ..., 2.0000000e+00,
#         4.5827998e+03, 1.5382014e-02],
#        [1.3899317e-01, 1.6834453e-01, 3.7482320e-03, ..., 2.0000000e+00,
#         4.0325000e+03, 5.1660247e-02],
#        ...,
#        [4.8101035e-01, 3.3863845e-01, 9.4947651e-02, ..., 2.0000000e+00,
#         4.7066001e+03, 1.4465750e-02],
#        [3.1863663e-01, 3.1321850e-01, 8.7106656e-03, ..., 2.0000000e+00,
#         3.9335000e+03, 1.4749498e-02],
#        [2.1876310e-01, 2.4897811e-01, 2.0529623e-03, ..., 3.0000000e+00,
#         3.4272000e+03, 3.7317887e-02]], shape=(20, 748), dtype=float32)

# %%
targets[:20]
# Out:
# array([[-1.5504026 , -4.3957977 , -2.6780095 , -6.5805817 , -5.696148  ,
#         -0.75622636, -8.        , -7.0171413 , -4.2355843 , -7.079722  ,
#         -5.576384  , -4.825992  ],
#        [-1.786195  , -2.426992  , -1.9918371 , -5.8557143 , -4.971281  ,
#         -1.8319873 , -5.608793  , -5.571096  , -3.1513147 , -7.509807  ,
#         -8.        , -6.4669204 ],
#        [-0.44997656, -2.264044  , -0.84085286, -6.434472  , -5.550039  ,
#         -0.39963904, -6.558032  , -7.5195484 , -6.708406  , -5.6008606 ,
#         -6.787589  , -3.7084947 ],
#        [-0.9329794 , -1.8840635 , -1.8755975 , -5.2551656 , -4.370732  ,
#         -0.24754822, -7.0999093 , -6.573034  , -4.927947  , -5.815988  ,
#         -7.8087635 , -7.513901  ],
#        [-1.6430966 , -2.4748607 , -1.7915479 , -6.4622355 , -5.577802  ,
#         -2.5608282 , -6.7508173 , -5.866287  , -3.2562702 , -8.        ,
#         -3.0636163 , -8.        ],
#        [-3.5304945 , -2.5916402 , -1.8778173 , -3.9678845 , -5.3836775 ,
#         -2.0417435 , -5.463229  , -6.132828  , -4.4016    , -7.5623217 ,
#         -7.7045355 , -8.        ],
#        [-1.0441366 , -2.1088865 , -1.1136911 , -6.5388346 , -5.654401  ,
#         -0.89772767, -5.7687593 , -4.4096384 , -2.2989993 , -5.693774  ,
#         -8.        , -4.807578  ],
#        [-2.9025903 , -2.0203342 , -1.9106497 , -5.7368073 , -4.8523736 ,
#         -1.2529941 , -6.6279235 , -6.6067414 , -6.863885  , -6.0866566 ,
#         -8.        , -7.0440965 ],
#        [-0.9065833 , -1.8855987 , -2.0396936 , -6.201524  , -5.31709   ,
#         -1.013441  , -7.639107  , -8.        , -7.0350027 , -6.481118  ,
#         -7.7435174 , -6.2105527 ],
#        [-3.4351327 , -2.2128282 , -2.2075288 , -6.18742   , -5.3029866 ,
#         -1.6824352 , -7.5685444 , -8.        , -3.3454702 , -5.273186  ,
#         -6.3525834 , -4.3584404 ],
#        [-3.4939373 , -1.8717883 , -1.4654676 , -6.237178  , -5.352744  ,
#         -0.2964816 , -5.7469697 , -5.526727  , -3.2012892 , -7.7316394 ,
#         -5.195302  , -5.5068874 ],
#        [-3.3411322 , -2.2961924 , -1.3863624 , -6.107881  , -3.9987025 ,
#         -0.37776646, -7.7777424 , -6.3802047 , -4.789875  , -6.71399   ,
#         -7.784207  , -7.77918   ],
#        [-1.1834985 , -2.0591495 , -2.0339556 , -5.77266   , -4.270443  ,
#         -0.94717544, -6.6181545 , -7.3550076 , -3.8994083 , -5.3783555 ,
#         -5.094229  , -3.5637102 ],
#        [-1.0353116 , -2.1535807 , -1.8049641 , -6.7023363 , -3.5535164 ,
#         -0.09820703, -3.8189278 , -2.562323  , -3.3821895 , -6.779154  ,
#         -6.5764294 , -6.4364924 ],
#        [-0.15128486, -0.43618414, -0.8528364 , -6.229024  , -5.34459   ,
#         -0.62599254, -6.040439  , -4.256875  , -5.7207947 , -5.6249437 ,
#         -7.0824976 , -6.0944157 ],
#        [-0.16466057, -1.1332407 , -0.88005316, -5.9523845 , -5.067951  ,
#         -1.687434  , -5.757751  , -5.587641  , -5.5602727 , -7.3754754 ,
#         -6.2925935 , -7.069237  ],
#        [-3.6614015 , -2.5698898 , -2.4604874 , -6.378878  , -4.4272165 ,
#         -0.7049994 , -7.561035  , -5.150054  , -4.2154107 , -6.9886193 ,
#         -4.7989135 , -7.6734667 ],
#        [-3.008443  , -2.5954866 , -2.3440163 , -5.826375  , -4.9419417 ,
#         -1.767106  , -7.7273016 , -5.8977118 , -3.1438665 , -8.        ,
#         -6.43867   , -5.65446   ],
#        [-0.9145305 , -1.678675  , -1.9454726 , -5.8356547 , -4.9512215 ,
#         -0.29723975, -5.704178  , -7.380723  , -6.248935  , -8.        ,
#         -7.829914  , -8.        ],
#        [-1.0290294 , -2.5707366 , -1.5175849 , -6.279109  , -5.3946753 ,
#         -1.0399407 , -6.782352  , -3.9539196 , -4.7969213 , -6.5711365 ,
#         -5.99103   , -6.124622  ]], dtype=float32)

# %%
# !python ./../src/predict.py ../inara_data/0021004.csv
# Out:
# Processing: 0021004.csv
#  H2O : -1.6424
#  CO2 : -2.2863
#   O2 : -1.3394
#   O3 : -5.5278
#  CH4 : -4.7228
#   N2 : -1.0894
#  N2O : -6.8077
#   CO : -5.0986
#   H2 : -4.6854
#  H2S : -6.0457
#  SO2 : -6.6295
#  NH3 : -5.3488
# ✅ HTML report generated → ../reports/prediction_report.html
#
# CSV saved → ../reports/prediction_20260402_085214.csv

# %%
for i in range(10):
    # !python ./../src/tune_xgboost.py --run_id {i}
# Out:
# Loaded: (10000, 748)
#
# Run ID: 0
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 900, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# Per-molecule R2: [-0.06429922580718994, -0.05955219268798828, -0.03745293617248535]
# Avg R2 (weak molecules): -0.05376811822255453
# Saved result 🚀
# Loaded: (10000, 748)
#
# Run ID: 1
# Params: {'max_depth': 4, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# Per-molecule R2: [-0.052620649337768555, -0.055179476737976074, -0.03462553024291992]
# Avg R2 (weak molecules): -0.047475218772888184
# Saved result 🚀
# Loaded: (10000, 748)
#
# Run ID: 2
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# Per-molecule R2: [-0.0771951675415039, -0.06875157356262207, -0.0503002405166626]
# Avg R2 (weak molecules): -0.06541566054026286
# Saved result 🚀
# Loaded: (10000, 748)
#
# Run ID: 3
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# Per-molecule R2: [-0.06832122802734375, -0.06676220893859863, -0.04379868507385254]
# Avg R2 (weak molecules): -0.059627374013264976
# Saved result 🚀
# Loaded: (10000, 748)
#
# Run ID: 4
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# Per-molecule R2: [-0.1097191572189331, -0.09969854354858398, -0.06952548027038574]
# Avg R2 (weak molecules): -0.0929810603459676
# Saved result 🚀
# Loaded: (10000, 748)
#
# Run ID: 5
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# Per-molecule R2: [-0.07602763175964355, -0.07348716259002686, -0.0532301664352417]
# Avg R2 (weak molecules): -0.0675816535949707
# Saved result 🚀
# Loaded: (10000, 748)
#
# Run ID: 6
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# Per-molecule R2: [-0.08852314949035645, -0.09776747226715088, -0.06330764293670654]
# Avg R2 (weak molecules): -0.08319942156473796
# Saved result 🚀
# Loaded: (10000, 748)
#
# Run ID: 7
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# Per-molecule R2: [-0.052198171615600586, -0.044670820236206055, -0.03229832649230957]
# Avg R2 (weak molecules): -0.04305577278137207
# Saved result 🚀
# Loaded: (10000, 748)
#
# Run ID: 8
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# Per-molecule R2: [-0.07673132419586182, -0.08112537860870361, -0.04671585559844971]
# Avg R2 (weak molecules): -0.06819085280100505
# Saved result 🚀
# Loaded: (10000, 748)
#
# Run ID: 9
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# Per-molecule R2: [-0.08852314949035645, -0.09776747226715088, -0.06330764293670654]
# Avg R2 (weak molecules): -0.08319942156473796
# Saved result 🚀

# %%
# !python ./../src/analyze_tuning.py
# Out:
# ==============================
# Top 5 Configurations
# ==============================
#
# Run ID: 7
# Avg R2: -0.0431
# Per Molecule R2: [-0.052198171615600586, -0.044670820236206055, -0.03229832649230957]
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# --------------------------------------------------
# Run ID: 1
# Avg R2: -0.0475
# Per Molecule R2: [-0.052620649337768555, -0.055179476737976074, -0.03462553024291992]
# Params: {'max_depth': 4, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# --------------------------------------------------
# Run ID: 0
# Avg R2: -0.0538
# Per Molecule R2: [-0.06429922580718994, -0.05955219268798828, -0.03745293617248535]
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 900, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# --------------------------------------------------
# Run ID: 3
# Avg R2: -0.0596
# Per Molecule R2: [-0.06832122802734375, -0.06676220893859863, -0.04379868507385254]
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# --------------------------------------------------
# Run ID: 2
# Avg R2: -0.0654
# Per Molecule R2: [-0.0771951675415039, -0.06875157356262207, -0.0503002405166626]
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# --------------------------------------------------

# %%
for mol in range(12):
    print(f"\n==== Molecule {mol} ====\n")

    for i in range(10):
        # !python ./../src/tune_xgboost.py --run_id {i} --mol_idx {mol}
# Out:
# ==== Molecule 0 ====
#
#
# Run ID: 0 | Molecule: 0
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 900, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 0): 0.9245782494544983
# Saved result 🚀
#
# Run ID: 1 | Molecule: 0
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 900, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 0): 0.926878809928894
# Saved result 🚀
#
# Run ID: 2 | Molecule: 0
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 0): 0.9123864769935608
# Saved result 🚀
#
# Run ID: 3 | Molecule: 0
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 0): 0.9273711442947388
# Saved result 🚀
#
# Run ID: 4 | Molecule: 0
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 0): 0.9217880964279175
# Saved result 🚀
#
# Run ID: 5 | Molecule: 0
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 0): 0.9177988171577454
# Saved result 🚀
#
# Run ID: 6 | Molecule: 0
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 900, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 0): 0.9271515607833862
# Saved result 🚀
#
# Run ID: 7 | Molecule: 0
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 0): 0.9192414283752441
# Saved result 🚀
#
# Run ID: 8 | Molecule: 0
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 0): 0.9109734296798706
# Saved result 🚀
#
# Run ID: 9 | Molecule: 0
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 0): 0.9270182251930237
# Saved result 🚀
#
# ==== Molecule 1 ====
#
#
# Run ID: 0 | Molecule: 1
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 1): 0.9448093175888062
# Saved result 🚀
#
# Run ID: 1 | Molecule: 1
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 1): 0.938319206237793
# Saved result 🚀
#
# Run ID: 2 | Molecule: 1
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 1): 0.9480355381965637
# Saved result 🚀
#
# Run ID: 3 | Molecule: 1
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 1): 0.9503324627876282
# Saved result 🚀
#
# Run ID: 4 | Molecule: 1
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 1): 0.948998212814331
# Saved result 🚀
#
# Run ID: 5 | Molecule: 1
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 1): 0.9446629285812378
# Saved result 🚀
#
# Run ID: 6 | Molecule: 1
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 900, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 1): 0.948123574256897
# Saved result 🚀
#
# Run ID: 7 | Molecule: 1
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 1): 0.9393449425697327
# Saved result 🚀
#
# Run ID: 8 | Molecule: 1
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 900, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 1): 0.9491498470306396
# Saved result 🚀
#
# Run ID: 9 | Molecule: 1
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 1): 0.9476786255836487
# Saved result 🚀
#
# ==== Molecule 2 ====
#
#
# Run ID: 0 | Molecule: 2
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 2): 0.9914799928665161
# Saved result 🚀
#
# Run ID: 1 | Molecule: 2
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.05, 'n_estimators': 900, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 2): 0.9906089901924133
# Saved result 🚀
#
# Run ID: 2 | Molecule: 2
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 2): 0.9896597266197205
# Saved result 🚀
#
# Run ID: 3 | Molecule: 2
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 2): 0.9908403754234314
# Saved result 🚀
#
# Run ID: 4 | Molecule: 2
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 2): 0.9913399815559387
# Saved result 🚀
#
# Run ID: 5 | Molecule: 2
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 900, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 2): 0.9914919137954712
# Saved result 🚀
#
# Run ID: 6 | Molecule: 2
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 2): 0.9914280772209167
# Saved result 🚀
#
# Run ID: 7 | Molecule: 2
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 2): 0.9911940097808838
# Saved result 🚀
#
# Run ID: 8 | Molecule: 2
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 2): 0.9906138181686401
# Saved result 🚀
#
# Run ID: 9 | Molecule: 2
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 2): 0.9915232062339783
# Saved result 🚀
#
# ==== Molecule 3 ====
#
#
# Run ID: 0 | Molecule: 3
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 900, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 3): 0.999668300151825
# Saved result 🚀
#
# Run ID: 1 | Molecule: 3
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 3): 0.9997826814651489
# Saved result 🚀
#
# Run ID: 2 | Molecule: 3
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 3): 0.9995993971824646
# Saved result 🚀
#
# Run ID: 3 | Molecule: 3
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 3): 0.9997777342796326
# Saved result 🚀
#
# Run ID: 4 | Molecule: 3
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 900, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 3): 0.9997187852859497
# Saved result 🚀
#
# Run ID: 5 | Molecule: 3
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 3): 0.9995734095573425
# Saved result 🚀
#
# Run ID: 6 | Molecule: 3
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 3): 0.9997665286064148
# Saved result 🚀
#
# Run ID: 7 | Molecule: 3
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 3): 0.9995376467704773
# Saved result 🚀
#
# Run ID: 8 | Molecule: 3
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 900, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 3): 0.9997773170471191
# Saved result 🚀
#
# Run ID: 9 | Molecule: 3
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 3): 0.9997236132621765
# Saved result 🚀
#
# ==== Molecule 4 ====
#
#
# Run ID: 0 | Molecule: 4
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 4): 0.9147356152534485
# Saved result 🚀
#
# Run ID: 1 | Molecule: 4
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 4): 0.9240675568580627
# Saved result 🚀
#
# Run ID: 2 | Molecule: 4
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 4): 0.9253923296928406
# Saved result 🚀
#
# Run ID: 3 | Molecule: 4
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 4): 0.9317368268966675
# Saved result 🚀
#
# Run ID: 4 | Molecule: 4
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 900, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 4): 0.9267376661300659
# Saved result 🚀
#
# Run ID: 5 | Molecule: 4
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 4): 0.9296760559082031
# Saved result 🚀
#
# Run ID: 6 | Molecule: 4
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 4): 0.9245061874389648
# Saved result 🚀
#
# Run ID: 7 | Molecule: 4
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 900, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 4): 0.9259739518165588
# Saved result 🚀
#
# Run ID: 8 | Molecule: 4
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 4): 0.928800642490387
# Saved result 🚀
#
# Run ID: 9 | Molecule: 4
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 4): 0.9255472421646118
# Saved result 🚀
#
# ==== Molecule 5 ====
#
#
# Run ID: 0 | Molecule: 5
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 5): -0.07058191299438477
# Saved result 🚀
#
# Run ID: 1 | Molecule: 5
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 900, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 5): -0.10050427913665771
# Saved result 🚀
#
# Run ID: 2 | Molecule: 5
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 5): -0.08352315425872803
# Saved result 🚀
#
# Run ID: 3 | Molecule: 5
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 5): -0.06484293937683105
# Saved result 🚀
#
# Run ID: 4 | Molecule: 5
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 900, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 5): -0.058410048484802246
# Saved result 🚀
#
# Run ID: 5 | Molecule: 5
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 900, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 5): -0.12674272060394287
# Saved result 🚀
#
# Run ID: 6 | Molecule: 5
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 5): -0.10049903392791748
# Saved result 🚀
#
# Run ID: 7 | Molecule: 5
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 5): -0.07879912853240967
# Saved result 🚀
#
# Run ID: 8 | Molecule: 5
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 5): -0.06309986114501953
# Saved result 🚀
#
# Run ID: 9 | Molecule: 5
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 5): -0.08481180667877197
# Saved result 🚀
#
# ==== Molecule 6 ====
#
#
# Run ID: 0 | Molecule: 6
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 6): -0.07133328914642334
# Saved result 🚀
#
# Run ID: 1 | Molecule: 6
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 900, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 6): -0.08256375789642334
# Saved result 🚀
#
# Run ID: 2 | Molecule: 6
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 6): -0.046475887298583984
# Saved result 🚀
#
# Run ID: 3 | Molecule: 6
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 6): -0.036767005920410156
# Saved result 🚀
#
# Run ID: 4 | Molecule: 6
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 6): -0.11208796501159668
# Saved result 🚀
#
# Run ID: 5 | Molecule: 6
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 6): -0.057239532470703125
# Saved result 🚀
#
# Run ID: 6 | Molecule: 6
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 6): -0.0880422592163086
# Saved result 🚀
#
# Run ID: 7 | Molecule: 6
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 6): -0.08636438846588135
# Saved result 🚀
#
# Run ID: 8 | Molecule: 6
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 6): -0.07270073890686035
# Saved result 🚀
#
# Run ID: 9 | Molecule: 6
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 900, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 6): -0.05955219268798828
# Saved result 🚀
#
# ==== Molecule 7 ====
#
#
# Run ID: 0 | Molecule: 7
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 7): -0.0290982723236084
# Saved result 🚀
#
# Run ID: 1 | Molecule: 7
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 7): -0.03478515148162842
# Saved result 🚀
#
# Run ID: 2 | Molecule: 7
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.05, 'n_estimators': 900, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 7): -0.07290112972259521
# Saved result 🚀
#
# Run ID: 3 | Molecule: 7
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 7): -0.02490091323852539
# Saved result 🚀
#
# Run ID: 4 | Molecule: 7
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 7): -0.056038737297058105
# Saved result 🚀
#
# Run ID: 5 | Molecule: 7
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 7): -0.04436647891998291
# Saved result 🚀
#
# Run ID: 6 | Molecule: 7
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 900, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 7): -0.07409548759460449
# Saved result 🚀
#
# Run ID: 7 | Molecule: 7
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 900, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 7): -0.038926005363464355
# Saved result 🚀
#
# Run ID: 8 | Molecule: 7
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 900, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 7): -0.07110273838043213
# Saved result 🚀
#
# Run ID: 9 | Molecule: 7
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 900, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 7): -0.03890562057495117
# Saved result 🚀
#
# ==== Molecule 8 ====
#
#
# Run ID: 0 | Molecule: 8
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 8): -0.02988147735595703
# Saved result 🚀
#
# Run ID: 1 | Molecule: 8
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 900, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 8): -0.0706413984298706
# Saved result 🚀
#
# Run ID: 2 | Molecule: 8
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 900, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 8): -0.07206177711486816
# Saved result 🚀
#
# Run ID: 3 | Molecule: 8
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 900, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 8): -0.05733382701873779
# Saved result 🚀
#
# Run ID: 4 | Molecule: 8
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 8): -0.02725374698638916
# Saved result 🚀
#
# Run ID: 5 | Molecule: 8
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 8): -0.06181669235229492
# Saved result 🚀
#
# Run ID: 6 | Molecule: 8
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 8): -0.04963862895965576
# Saved result 🚀
#
# Run ID: 7 | Molecule: 8
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 8): -0.03977692127227783
# Saved result 🚀
#
# Run ID: 8 | Molecule: 8
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.05, 'n_estimators': 900, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 8): -0.06141376495361328
# Saved result 🚀
#
# Run ID: 9 | Molecule: 8
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 8): -0.02496469020843506
# Saved result 🚀
#
# ==== Molecule 9 ====
#
#
# Run ID: 0 | Molecule: 9
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 900, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 9): -0.053148508071899414
# Saved result 🚀
#
# Run ID: 1 | Molecule: 9
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 900, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 9): -0.08533239364624023
# Saved result 🚀
#
# Run ID: 2 | Molecule: 9
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 900, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 9): -0.07558798789978027
# Saved result 🚀
#
# Run ID: 3 | Molecule: 9
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 9): -0.05551779270172119
# Saved result 🚀
#
# Run ID: 4 | Molecule: 9
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 9): -0.06036686897277832
# Saved result 🚀
#
# Run ID: 5 | Molecule: 9
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 9): -0.06264281272888184
# Saved result 🚀
#
# Run ID: 6 | Molecule: 9
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 900, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 9): -0.07397472858428955
# Saved result 🚀
#
# Run ID: 7 | Molecule: 9
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 900, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 9): -0.03964269161224365
# Saved result 🚀
#
# Run ID: 8 | Molecule: 9
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 9): -0.06298863887786865
# Saved result 🚀
#
# Run ID: 9 | Molecule: 9
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 9): -0.06298863887786865
# Saved result 🚀
#
# ==== Molecule 10 ====
#
#
# Run ID: 0 | Molecule: 10
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 10): -0.042865753173828125
# Saved result 🚀
#
# Run ID: 1 | Molecule: 10
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 10): -0.04487192630767822
# Saved result 🚀
#
# Run ID: 2 | Molecule: 10
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 10): -0.017982840538024902
# Saved result 🚀
#
# Run ID: 3 | Molecule: 10
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 10): -0.034265995025634766
# Saved result 🚀
#
# Run ID: 4 | Molecule: 10
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 10): -0.021630167961120605
# Saved result 🚀
#
# Run ID: 5 | Molecule: 10
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 10): -0.034265995025634766
# Saved result 🚀
#
# Run ID: 6 | Molecule: 10
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 10): -0.0398104190826416
# Saved result 🚀
#
# Run ID: 7 | Molecule: 10
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 10): -0.027999162673950195
# Saved result 🚀
#
# Run ID: 8 | Molecule: 10
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 10): -0.03865385055541992
# Saved result 🚀
#
# Run ID: 9 | Molecule: 10
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 900, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 10): -0.04849410057067871
# Saved result 🚀
#
# ==== Molecule 11 ====
#
#
# Run ID: 0 | Molecule: 11
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 900, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 11): -0.09164059162139893
# Saved result 🚀
#
# Run ID: 1 | Molecule: 11
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 11): -0.04464566707611084
# Saved result 🚀
#
# Run ID: 2 | Molecule: 11
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 900, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# R2 (molecule 11): -0.08532369136810303
# Saved result 🚀
#
# Run ID: 3 | Molecule: 11
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 11): -0.08990597724914551
# Saved result 🚀
#
# Run ID: 4 | Molecule: 11
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 11): -0.05871915817260742
# Saved result 🚀
#
# Run ID: 5 | Molecule: 11
# Loaded: (10000, 748)
# Params: {'max_depth': 5, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 11): -0.06948220729827881
# Saved result 🚀
#
# Run ID: 6 | Molecule: 11
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 11): -0.05245816707611084
# Saved result 🚀
#
# Run ID: 7 | Molecule: 11
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# R2 (molecule 11): -0.0893101692199707
# Saved result 🚀
#
# Run ID: 8 | Molecule: 11
# Loaded: (10000, 748)
# Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# R2 (molecule 11): -0.06928980350494385
# Saved result 🚀
#
# Run ID: 9 | Molecule: 11
# Loaded: (10000, 748)
# Params: {'max_depth': 4, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# R2 (molecule 11): -0.08084821701049805
# Saved result 🚀

# %%
# !python ./../src/analyze_tuning.py
# Out:
# ==============================
# Per-Molecule Best Configurations
# ==============================
#
#
# ===== molecule_0 =====
# Best R2: 0.9274
# Best Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# Saved best.json
# --------------------------------------------------
#
# ===== molecule_1 =====
# Best R2: 0.9503
# Best Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# Saved best.json
# --------------------------------------------------
#
# ===== molecule_10 =====
# Best R2: -0.0180
# Best Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# Saved best.json
# --------------------------------------------------
#
# ===== molecule_11 =====
# Best R2: -0.0446
# Best Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# Saved best.json
# --------------------------------------------------
#
# ===== molecule_2 =====
# Best R2: 0.9915
# Best Params: {'max_depth': 6, 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.6, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# Saved best.json
# --------------------------------------------------
#
# ===== molecule_3 =====
# Best R2: 0.9998
# Best Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# Saved best.json
# --------------------------------------------------
#
# ===== molecule_4 =====
# Best R2: 0.9317
# Best Params: {'max_depth': 6, 'learning_rate': 0.03, 'n_estimators': 700, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# Saved best.json
# --------------------------------------------------
#
# ===== molecule_5 =====
# Best R2: -0.0584
# Best Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 900, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 1.5}
# Saved best.json
# --------------------------------------------------
#
# ===== molecule_6 =====
# Best R2: -0.0368
# Best Params: {'max_depth': 4, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# Saved best.json
# --------------------------------------------------
#
# ===== molecule_7 =====
# Best R2: -0.0249
# Best Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 1.5}
# Saved best.json
# --------------------------------------------------
#
# ===== molecule_8 =====
# Best R2: -0.0250
# Best Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 500, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 2.0}
# Saved best.json
# --------------------------------------------------
#
# ===== molecule_9 =====
# Best R2: -0.0396
# Best Params: {'max_depth': 5, 'learning_rate': 0.03, 'n_estimators': 900, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_alpha': 0.5, 'reg_lambda': 2.0}
# Saved best.json
# --------------------------------------------------
