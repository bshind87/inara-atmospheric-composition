# %% [markdown]
# ## Imports and path definitions

# %%
import os
import sys
import pandas as pd
import numpy as np

# Get project root (one level up from notebooks/)
PROJECT_ROOT = os.path.abspath("..")

# Add src to path
SRC_PATH = os.path.join(PROJECT_ROOT, "src")
sys.path.append(SRC_PATH)

print("Project root:", PROJECT_ROOT)
print("Src path:", SRC_PATH)
# Out:
# Project root: /Users/bhalchandra/myPythonCode/inara-atmospheric-composition
# Src path: /Users/bhalchandra/myPythonCode/inara-atmospheric-composition/src

# %% [markdown]
# ## Get source Data ready

# %%
df = pd.read_csv("../inara_data/psg_models.csv")
print(df.columns.tolist())
# Out:
# ['PlanetIndex', 'star_class', 'star_temperature_in_Kelvin', 'star_radius_in_Solar_radii', 'distance_from_Earth_to_the_system_in_parsecs', 'semimajor_axis_of_the_planet_in_AU', 'planet_radius_in_km', 'planet_density', 'planet_surface_pressure_bars', 'kappa', 'gamma1', 'gamma2', 'alpha', 'beta', 'planet_surface_temperature_Kelvin', 'H2O', 'CO2', 'O2', 'N2', 'CH4', 'N2O', 'CO', 'O3', 'SO2', 'NH3', 'C2H6', 'NO2', 'planet_atmospheres_avg_mol_wgt', 'planets_mean_surface_albedo']

# %%
# !python ./../src/extract_inara_data.py
# Out:
# 17:56:24  Using 3503 CSV files
# 17:56:24  Loaded labels: (8879, 28)
# 17:56:25  500/3503 processed
# 17:56:27  1000/3503 processed
# 17:56:28  1500/3503 processed
# 17:56:30  2000/3503 processed
# 17:56:31  2500/3503 processed
# 17:56:32  3000/3503 processed
# 17:56:34  3500/3503 processed
# 17:56:34  Parsed 3503 ok | 0 failed
# 17:56:34  Saved processed data
# 17:56:34  spectra: (3503, 3, 4378)
# 17:56:34  molecules: (3503, 12)

# %% [markdown]
# ## XGBoost process

# %%
# !python ./../src/xgboost_feature_eng_v2.py
# Out:
# Loading data...
# Processing 0/3503
# Processing 2000/3503
# Raw shape: (3503, 4105)
# Final shape: (3503, 3020)
# Features saved 🚀

# %%
# !python ./../src/xgboost_train_v2.py
# Out:
# Loaded: (3503, 3020) (3503, 12)
# Training molecule 0
# Training molecule 1
# Training molecule 2
# Training molecule 3
# Training molecule 4
# Training molecule 5
# Training molecule 6
# Training molecule 7
# Training molecule 8
# Training molecule 9
# Training molecule 10
# Training molecule 11
#
# === VALIDATION METRICS (OVERALL) ===
# R2   : 0.3397967666387558
# RMSE : 0.36042042722926804
# MAE  : 0.2538950741291046
#
# === PER MOLECULE METRICS ===
# H2O → R2=0.524, RMSE=0.293, MAE=0.217
# CO2 → R2=0.342, RMSE=0.292, MAE=0.206
# O2 → R2=0.489, RMSE=0.281, MAE=0.192
# O3 → R2=0.820, RMSE=0.238, MAE=0.175
# CH4 → R2=0.519, RMSE=0.283, MAE=0.200
# N2 → R2=-0.049, RMSE=0.376, MAE=0.279
# N2O → R2=0.155, RMSE=0.398, MAE=0.285
# CO → R2=-0.041, RMSE=0.492, MAE=0.352
# H2 → R2=-0.031, RMSE=0.441, MAE=0.330
# H2S → R2=0.696, RMSE=0.240, MAE=0.165
# SO2 → R2=0.187, RMSE=0.512, MAE=0.389
# NH3 → R2=0.467, RMSE=0.339, MAE=0.258
#
# === TEST METRICS (OVERALL) ===
# R2   : 0.33019933601220447
# RMSE : 0.37406871312462103
# MAE  : 0.2592158615589142
#
# === PER MOLECULE METRICS ===
# H2O → R2=0.449, RMSE=0.352, MAE=0.250
# CO2 → R2=0.335, RMSE=0.308, MAE=0.201
# O2 → R2=0.544, RMSE=0.266, MAE=0.181
# O3 → R2=0.835, RMSE=0.231, MAE=0.169
# CH4 → R2=0.573, RMSE=0.307, MAE=0.203
# N2 → R2=-0.119, RMSE=0.399, MAE=0.271
# N2O → R2=0.145, RMSE=0.407, MAE=0.295
# CO → R2=-0.076, RMSE=0.477, MAE=0.352
# H2 → R2=0.049, RMSE=0.467, MAE=0.344
# H2S → R2=0.718, RMSE=0.247, MAE=0.176
# SO2 → R2=0.233, RMSE=0.527, MAE=0.392
# NH3 → R2=0.276, RMSE=0.367, MAE=0.277
#
# Training complete 🚀

# %%
# !python ./../src/xgboost_evaluate_v2.py
# Out:
# Loaded test: (526, 3020) (526, 12)
#
# === TEST METRICS (OVERALL) ===
# R2   : 0.3301993211110433
# RMSE : 0.37406871312462103
# MAE  : 0.2592158615589142
#
# === PER MOLECULE METRICS ===
# H2O → R2=0.449, RMSE=0.352, MAE=0.250
# CO2 → R2=0.335, RMSE=0.308, MAE=0.201
# O2 → R2=0.544, RMSE=0.266, MAE=0.181
# O3 → R2=0.835, RMSE=0.231, MAE=0.169
# CH4 → R2=0.573, RMSE=0.307, MAE=0.203
# N2 → R2=-0.119, RMSE=0.399, MAE=0.271
# N2O → R2=0.145, RMSE=0.407, MAE=0.295
# CO → R2=-0.076, RMSE=0.477, MAE=0.352
# H2 → R2=0.049, RMSE=0.467, MAE=0.344
# H2S → R2=0.718, RMSE=0.247, MAE=0.176
# SO2 → R2=0.233, RMSE=0.527, MAE=0.392
# NH3 → R2=0.276, RMSE=0.367, MAE=0.277
#
# Evaluation complete 🚀

# %% [markdown]
# ## 1D CNN

# %%
# !python ./../src/train.py
# Out:
# Device: mps
# Train: 2,452  Val: 525  Test: 526
# Train: 2,452  Val: 525  Test: 526
# Parameters: 18,075,084
# /opt/anaconda3/envs/ML/lib/python3.13/site-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
#
# === TARGET DISTRIBUTION (VALIDATION) ===
# H2O: mean=-1.613, std=0.421883, min=-3.315, max=-0.708
# CO2: mean=-0.614, std=0.359083, min=-2.693, max=-0.083
# O2: mean=-0.626, std=0.386503, min=-3.183, max=-0.111
# O3: mean=-3.058, std=0.562342, min=-5.439, max=-2.184
# CH4: mean=-1.606, std=0.429431, min=-3.817, max=-0.804
# N2: mean=-0.626, std=0.378243, min=-4.111, max=-0.107
# N2O: mean=-2.303, std=0.428110, min=-4.016, max=-1.470
# CO: mean=-2.347, std=0.473739, min=-4.898, max=-1.476
# H2: mean=-2.320, std=0.423811, min=-4.574, max=-1.337
# H2S: mean=-2.661, std=0.463111, min=-5.479, max=-1.491
# SO2: mean=-4.041, std=0.588001, min=-7.413, max=-2.909
# NH3: mean=-5.324, std=0.420570, min=-7.192, max=-4.317
# Ep 001/150  train=7.4529  val=5.7606  RMSE=2.4001  MAE=1.9916  R2=-25.900  best_mol=O2(0.385)  worst_mol=NH3(4.513)  t=11.7s
#   → New best val loss: 5.7606 (saved)
# Ep 002/150  train=4.4090  val=2.1005  RMSE=1.4493  MAE=1.1596  R2=-8.956  best_mol=O2(0.384)  worst_mol=NH3(2.750)  t=3.3s
#   → New best val loss: 2.1005 (saved)
# Ep 003/150  train=2.5974  val=1.2371  RMSE=1.1122  MAE=0.8279  R2=-5.103  best_mol=O2(0.388)  worst_mol=NH3(2.167)  t=3.1s
#   → New best val loss: 1.2371 (saved)
# Ep 004/150  train=1.5035  val=1.3517  RMSE=1.1626  MAE=0.8173  R2=-5.483  best_mol=CO2(0.402)  worst_mol=NH3(2.261)  t=3.1s
# Ep 005/150  train=0.9442  val=1.5705  RMSE=1.2532  MAE=0.8826  R2=-6.604  best_mol=CO2(0.441)  worst_mol=NH3(2.520)  t=3.1s
# Ep 006/150  train=0.6753  val=1.2660  RMSE=1.1252  MAE=0.8117  R2=-5.193  best_mol=CO2(0.387)  worst_mol=NH3(2.342)  t=3.2s
# Ep 007/150  train=0.5317  val=1.1949  RMSE=1.0931  MAE=0.7714  R2=-4.821  best_mol=CO2(0.385)  worst_mol=NH3(2.284)  t=3.1s
#   → New best val loss: 1.1949 (saved)
# Ep 008/150  train=0.4872  val=0.9017  RMSE=0.9496  MAE=0.6778  R2=-3.349  best_mol=CO2(0.364)  worst_mol=NH3(1.921)  t=3.1s
#   → New best val loss: 0.9017 (saved)
# Ep 009/150  train=0.4660  val=0.8794  RMSE=0.9378  MAE=0.6699  R2=-3.202  best_mol=CO2(0.366)  worst_mol=NH3(1.820)  t=3.1s
#   → New best val loss: 0.8794 (saved)
# Ep 010/150  train=0.4564  val=0.7354  RMSE=0.8575  MAE=0.6237  R2=-2.528  best_mol=CO2(0.363)  worst_mol=NH3(1.619)  t=3.1s
#   → New best val loss: 0.7354 (saved)
# Ep 011/150  train=0.4479  val=0.8113  RMSE=0.9007  MAE=0.6458  R2=-2.849  best_mol=CO2(0.369)  worst_mol=NH3(1.663)  t=3.1s
# Ep 012/150  train=0.4374  val=0.7284  RMSE=0.8534  MAE=0.6121  R2=-2.481  best_mol=CO2(0.360)  worst_mol=NH3(1.567)  t=3.2s
#   → New best val loss: 0.7284 (saved)
# Ep 013/150  train=0.4300  val=0.6618  RMSE=0.8135  MAE=0.5800  R2=-2.137  best_mol=CO2(0.357)  worst_mol=NH3(1.442)  t=3.1s
#   → New best val loss: 0.6618 (saved)
# Ep 014/150  train=0.4247  val=0.5998  RMSE=0.7745  MAE=0.5502  R2=-1.824  best_mol=CO2(0.359)  worst_mol=NH3(1.306)  t=3.1s
#   → New best val loss: 0.5998 (saved)
# Ep 015/150  train=0.4045  val=0.5729  RMSE=0.7569  MAE=0.5451  R2=-1.685  best_mol=CO2(0.360)  worst_mol=NH3(1.248)  t=3.1s
#   → New best val loss: 0.5729 (saved)
# Ep 016/150  train=0.3984  val=0.5599  RMSE=0.7483  MAE=0.5400  R2=-1.591  best_mol=CO2(0.356)  worst_mol=O3(1.222)  t=3.2s
#   → New best val loss: 0.5599 (saved)
# Ep 017/150  train=0.3833  val=0.5330  RMSE=0.7301  MAE=0.5277  R2=-1.461  best_mol=CO2(0.358)  worst_mol=O3(1.223)  t=3.0s
#   → New best val loss: 0.5330 (saved)
# Ep 018/150  train=0.3713  val=0.5302  RMSE=0.7281  MAE=0.5254  R2=-1.445  best_mol=CO2(0.361)  worst_mol=O3(1.248)  t=3.1s
#   → New best val loss: 0.5302 (saved)
# Ep 019/150  train=0.3734  val=0.5175  RMSE=0.7194  MAE=0.5184  R2=-1.375  best_mol=CO2(0.363)  worst_mol=O3(1.265)  t=3.1s
#   → New best val loss: 0.5175 (saved)
# Ep 020/150  train=0.3760  val=0.4674  RMSE=0.6836  MAE=0.4942  R2=-1.143  best_mol=CO2(0.360)  worst_mol=O3(1.212)  t=3.0s
#   → New best val loss: 0.4674 (saved)
# Ep 021/150  train=0.3617  val=0.4454  RMSE=0.6674  MAE=0.4795  R2=-1.044  best_mol=CO2(0.356)  worst_mol=O3(1.200)  t=3.1s
#   → New best val loss: 0.4454 (saved)
# Ep 022/150  train=0.3530  val=0.4265  RMSE=0.6530  MAE=0.4664  R2=-0.969  best_mol=CO2(0.357)  worst_mol=O3(1.154)  t=3.1s
#   → New best val loss: 0.4265 (saved)
# Ep 023/150  train=0.3490  val=0.4108  RMSE=0.6409  MAE=0.4605  R2=-0.910  best_mol=CO2(0.360)  worst_mol=O3(1.097)  t=3.0s
#   → New best val loss: 0.4108 (saved)
# Ep 024/150  train=0.3546  val=0.4305  RMSE=0.6561  MAE=0.4675  R2=-0.980  best_mol=CO2(0.361)  worst_mol=O3(1.151)  t=3.1s
# Ep 025/150  train=0.3392  val=0.3936  RMSE=0.6274  MAE=0.4503  R2=-0.799  best_mol=CO2(0.358)  worst_mol=O3(1.139)  t=3.0s
#   → New best val loss: 0.3936 (saved)
# Ep 026/150  train=0.3351  val=0.4246  RMSE=0.6516  MAE=0.4670  R2=-0.950  best_mol=CO2(0.360)  worst_mol=O3(1.148)  t=3.1s
# Ep 027/150  train=0.3300  val=0.4588  RMSE=0.6774  MAE=0.4864  R2=-1.125  best_mol=CO2(0.364)  worst_mol=O3(1.163)  t=3.1s
# Ep 028/150  train=0.3262  val=0.4042  RMSE=0.6358  MAE=0.4575  R2=-0.872  best_mol=CO2(0.361)  worst_mol=O3(1.098)  t=3.1s
# Ep 029/150  train=0.3204  val=0.4189  RMSE=0.6472  MAE=0.4618  R2=-0.934  best_mol=CO2(0.361)  worst_mol=O3(1.124)  t=3.1s
# Ep 030/150  train=0.3233  val=0.4523  RMSE=0.6726  MAE=0.4791  R2=-1.101  best_mol=CO2(0.362)  worst_mol=O3(1.145)  t=3.1s
# Ep 031/150  train=0.3159  val=0.4851  RMSE=0.6965  MAE=0.4988  R2=-1.238  best_mol=CO2(0.363)  worst_mol=O3(1.197)  t=3.1s  lr→5.00e-04
# Ep 032/150  train=0.3114  val=0.5031  RMSE=0.7093  MAE=0.5018  R2=-1.308  best_mol=CO2(0.361)  worst_mol=O3(1.239)  t=3.1s
# Ep 033/150  train=0.3070  val=0.5502  RMSE=0.7417  MAE=0.5247  R2=-1.540  best_mol=CO2(0.362)  worst_mol=NH3(1.240)  t=3.1s
# Ep 034/150  train=0.3039  val=0.6042  RMSE=0.7773  MAE=0.5501  R2=-1.793  best_mol=CO2(0.365)  worst_mol=NH3(1.338)  t=3.0s
# Ep 035/150  train=0.3049  val=0.6293  RMSE=0.7933  MAE=0.5585  R2=-1.905  best_mol=CO2(0.369)  worst_mol=NH3(1.371)  t=3.1s
# Ep 036/150  train=0.2988  val=0.5200  RMSE=0.7211  MAE=0.5111  R2=-1.403  best_mol=CO2(0.365)  worst_mol=O3(1.225)  t=3.1s
# Ep 037/150  train=0.3000  val=0.6149  RMSE=0.7842  MAE=0.5527  R2=-1.853  best_mol=CO2(0.373)  worst_mol=NH3(1.354)  t=3.1s  lr→2.50e-04
# Ep 038/150  train=0.2934  val=0.5721  RMSE=0.7563  MAE=0.5322  R2=-1.639  best_mol=CO2(0.369)  worst_mol=NH3(1.291)  t=3.0s
# Ep 039/150  train=0.2914  val=0.6090  RMSE=0.7804  MAE=0.5508  R2=-1.802  best_mol=CO2(0.371)  worst_mol=NH3(1.336)  t=3.1s
# Ep 040/150  train=0.2922  val=0.6314  RMSE=0.7946  MAE=0.5613  R2=-1.902  best_mol=CO2(0.371)  worst_mol=NH3(1.370)  t=3.0s
# Early stopping at epoch 40
#
# History saved to /Users/bhalchandra/myPythonCode/inara-atmospheric-composition/results/training_history.json
# Best checkpoint: /Users/bhalchandra/myPythonCode/inara-atmospheric-composition/checkpoints/best_model.pt
#
# === BEST PER-MOLECULE (VALIDATION) ===
# H2O    → RMSE=0.445  MAE=0.330  R2=-0.114  Var=0.177985
# CO2    → RMSE=0.356  MAE=0.243  R2=0.018  Var=0.128940
# O2     → RMSE=0.384  MAE=0.260  R2=0.014  Var=0.149384
# O3     → RMSE=1.039  MAE=0.820  R2=-2.412  Var=0.316228
# CH4    → RMSE=0.453  MAE=0.346  R2=-0.112  Var=0.184411
# N2     → RMSE=0.416  MAE=0.266  R2=-0.210  Var=0.143068
# N2O    → RMSE=0.533  MAE=0.409  R2=-0.549  Var=0.183278
# CO     → RMSE=0.576  MAE=0.432  R2=-0.477  Var=0.224429
# H2     → RMSE=0.527  MAE=0.407  R2=-0.548  Var=0.179616
# H2S    → RMSE=0.484  MAE=0.352  R2=-0.093  Var=0.214472
# SO2    → RMSE=0.804  MAE=0.634  R2=-0.870  Var=0.345746
# NH3    → RMSE=0.871  MAE=0.693  R2=-3.291  Var=0.176879
#
# === BEST GLOBAL (VALIDATION) ===
# RMSE: 0.6274
# MAE : 0.4503
# R2  : -0.7986

# %%
# !python ./../src/evaluate.py --mc 50
# Out:
# Loaded checkpoint: /Users/bhalchandra/myPythonCode/inara-atmospheric-composition/checkpoints/best_model.pt (epoch 25)
# Train: 2,452  Val: 525  Test: 526
# Running MC Dropout (50 samples)...
# /opt/anaconda3/envs/ML/lib/python3.13/site-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
#
# === PER-MOLECULE METRICS ===
# Mol       RMSE     MAE      R²    NRMSE   Cov95
# ───────────────────────────────────────────────────────
# H2O      0.461   0.342  -0.002    0.286   0.840
# CO2      0.384   0.263   0.046    0.597   0.795
# O2       0.370   0.253   0.236    0.583   0.785
# O3       0.438   0.339   0.492    0.143   0.909
# CH4      0.440   0.330   0.058    0.269   0.842
# N2       0.399   0.271  -0.014    0.643   0.859
# N2O      0.464   0.349  -0.128    0.202   0.907
# CO       0.493   0.367  -0.077    0.214   0.869
# H2       0.524   0.366  -0.065    0.225   0.867
# H2S      0.439   0.321   0.122    0.167   0.899
# SO2      0.627   0.477   0.004    0.155   0.867
# NH3      0.536   0.395  -0.350    0.101   0.913
# ───────────────────────────────────────────────────────
# Mean     0.465   0.340   0.027    0.299   0.863
#
# === GLOBAL METRICS ===
# RMSE : 0.4696
# MAE  : 0.3397
# R²   : 0.8931
#
# Saved metrics to: /Users/bhalchandra/myPythonCode/inara-atmospheric-composition/results/plots/metrics.csv

# %%
import os
import numpy as np

# ── PATH ─────────────────────────────────────────────
DATA_DIR = "../inara_data/processed"

spectra_path = os.path.join(DATA_DIR, "spectra.npy")
mols_path    = os.path.join(DATA_DIR, "molecules.npy")
ids_path     = os.path.join(DATA_DIR, "system_ids.npy")

# ── LOAD ────────────────────────────────────────────
spectra = np.load(spectra_path)
mols    = np.load(mols_path)
ids     = np.load(ids_path)

MOLECULES = [
    'H2O','CO2','O2','O3','CH4','N2',
    'N2O','CO','SO2','NH3','C2H6','NO2'
]

print("\n=== DATA SHAPES ===")
print("Spectra :", spectra.shape)
print("Molecules:", mols.shape)
print("IDs     :", ids.shape)

# ── GLOBAL CHECK ─────────────────────────────────────
print("\n=== GLOBAL STATS ===")
print("Spectra min/max:", np.min(spectra), np.max(spectra))
print("Molecules min/max:", np.min(mols), np.max(mols))
print("Molecules std (global):", np.std(mols))

# ── CHECK IF ALL ZERO ────────────────────────────────
print("\n=== ZERO CHECK ===")
print("All molecules zero?:", np.all(mols == 0))

# ── PER MOLECULE ANALYSIS ────────────────────────────
print("\n=== PER-MOLECULE STATS ===")

for i, mol in enumerate(MOLECULES):
    y = mols[:, i]

    print(f"\n{mol}:")
    print(f"  unique values (first 10): {np.unique(y)[:10]}")
    print(f"  min={np.min(y):.6f}")
    print(f"  max={np.max(y):.6f}")
    print(f"  mean={np.mean(y):.6f}")
    print(f"  std={np.std(y):.6f}")

# ── CHECK NaNs ───────────────────────────────────────
print("\n=== NaN CHECK ===")
print("NaNs in spectra:", np.isnan(spectra).sum())
print("NaNs in molecules:", np.isnan(mols).sum())

# ── SAMPLE CHECK ─────────────────────────────────────
print("\n=== SAMPLE ROW (first) ===")
print("Molecules[0]:", mols[0])

# ── DISTRIBUTION SUMMARY ─────────────────────────────
print("\n=== VARIANCE SUMMARY ===")
low_var_count = 0

for i, mol in enumerate(MOLECULES):
    std = np.std(mols[:, i])
    if std < 1e-6:
        low_var_count += 1
        print(f"{mol} → LOW VARIANCE ⚠️ (std={std:.8f})")

print(f"\nLow variance molecules: {low_var_count}/{len(MOLECULES)}")

print("\n=== DONE ===")
# Out:
# === DATA SHAPES ===
# Spectra : (3503, 3, 4378)
# Molecules: (3503, 12)
# IDs     : (3503,)
#
# === GLOBAL STATS ===
# Spectra min/max: -0.5621077 0.9972109
# Molecules min/max: -8.868874 -0.053141244
# Molecules std (global): 1.4375783
#
# === ZERO CHECK ===
# All molecules zero?: False
#
# === PER-MOLECULE STATS ===
#
# H2O:
#   unique values (first 10): [-5.5313416 -4.4617076 -4.389549  -4.185117  -3.8956459 -3.8738298
#  -3.775327  -3.7649562 -3.749824  -3.6598272]
#   min=-5.531342
#   max=-0.583778
#   mean=-1.624125
#   std=0.457699
#
# CO2:
#   unique values (first 10): [-3.7904575 -3.7050273 -2.9800324 -2.83137   -2.7071645 -2.693375
#  -2.6430063 -2.5686414 -2.521961  -2.5213392]
#   min=-3.790457
#   max=-0.080435
#   mean=-0.619623
#   std=0.378007
#
# O2:
#   unique values (first 10): [-3.6698995 -3.5364716 -3.5269737 -3.3577614 -3.1825418 -3.0948904
#  -2.929484  -2.8368697 -2.7181015 -2.7041981]
#   min=-3.669899
#   max=-0.053141
#   mean=-0.631964
#   std=0.392581
#
# O3:
#   unique values (first 10): [-6.3504333 -6.2579103 -6.0424833 -5.916197  -5.8960295 -5.891167
#  -5.846917  -5.702594  -5.6491504 -5.6170177]
#   min=-6.350433
#   max=-2.100800
#   mean=-3.070801
#   std=0.592410
#
# CH4:
#   unique values (first 10): [-5.757705  -4.624816  -4.1020575 -3.980815  -3.8393376 -3.824915
#  -3.8228939 -3.8165467 -3.7946606 -3.7323663]
#   min=-5.757705
#   max=-0.612777
#   mean=-1.621490
#   std=0.443514
#
# N2:
#   unique values (first 10): [-4.1105056 -3.7650616 -3.5994775 -2.8241596 -2.822293  -2.7761655
#  -2.7633636 -2.7124536 -2.6860754 -2.5493426]
#   min=-4.110506
#   max=-0.083859
#   mean=-0.622624
#   std=0.374204
#
# N2O:
#   unique values (first 10): [-5.8223877 -4.8745027 -4.871488  -4.6191416 -4.526001  -4.480046
#  -4.4063888 -4.372956  -4.2942624 -4.226814 ]
#   min=-5.822388
#   max=-1.032970
#   mean=-2.322139
#   std=0.455128
#
# CO:
#   unique values (first 10): [-6.0001173 -5.175519  -4.8981566 -4.846514  -4.754568  -4.6786337
#  -4.521636  -4.48874   -4.464755  -4.370544 ]
#   min=-6.000117
#   max=-1.013274
#   mean=-2.334380
#   std=0.463714
#
# SO2:
#   unique values (first 10): [-5.549476  -5.3434243 -5.06581   -4.925802  -4.795423  -4.641912
#  -4.573804  -4.536667  -4.461949  -4.428597 ]
#   min=-5.549476
#   max=-1.287244
#   mean=-2.314620
#   std=0.450822
#
# NH3:
#   unique values (first 10): [-6.2378163 -5.639804  -5.479272  -5.471569  -5.16538   -5.1590905
#  -4.923335  -4.809074  -4.782905  -4.73992  ]
#   min=-6.237816
#   max=-1.458921
#   mean=-2.627183
#   std=0.466429
#
# C2H6:
#   unique values (first 10): [-8.0544615 -7.6872845 -7.413201  -6.8019934 -6.7589874 -6.703712
#  -6.6103673 -6.552281  -6.4940953 -6.4455557]
#   min=-8.054461
#   max=-2.677424
#   mean=-4.048440
#   std=0.600340
#
# NO2:
#   unique values (first 10): [-8.868874  -8.472726  -7.971191  -7.811756  -7.747478  -7.739309
#  -7.735934  -7.6585264 -7.5075336 -7.3521867]
#   min=-8.868874
#   max=-4.236897
#   mean=-5.319763
#   std=0.449996
#
# === NaN CHECK ===
# NaNs in spectra: 0
# NaNs in molecules: 0
#
# === SAMPLE ROW (first) ===
# Molecules[0]: [-2.0019698  -0.74310124 -0.4083297  -2.8408427  -1.8639576  -0.40930954
#  -2.5093849  -2.5824919  -2.1937923  -2.718814   -5.0200033  -5.0117116 ]
#
# === VARIANCE SUMMARY ===
#
# Low variance molecules: 0/12
#
# === DONE ===
